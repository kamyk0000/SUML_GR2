# %%
import pandas as pd

drug_df = pd.read_csv("Data/drug200.csv")
drug_df = drug_df.sample(frac=1)
drug_df.head(3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import pandas as pd
#       3 drug_df = pd.read_csv("Data/drug200.csv")
#       4 drug_df = drug_df.sample(frac=1)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
from sklearn.model_selection import train_test_split

X = drug_df.drop("Drug", axis=1).values
y = drug_df.Drug.values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=125
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X = drug_df.drop("Drug", axis=1).values
#       4 y = drug_df.Drug.values
#       6 X_train, X_test, y_train, y_test = train_test_split(
#       7     X, y, test_size=0.3, random_state=125
#       8 )
#
# NameError: name 'drug_df' is not defined

# %%
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

cat_col = [1,2,3]
num_col = [0,4]

transform = ColumnTransformer(
    [
        ("encoder", OrdinalEncoder(), cat_col),
        ("num_imputer", SimpleImputer(strategy="median"), num_col),
        ("num_scaler", StandardScaler(), num_col),
    ]
)
pipe = Pipeline(
    steps=[
        ("preprocessing", transform),
        ("model", RandomForestClassifier(n_estimators=100, random_state=125)),
    ]
)
pipe.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 23
#      10 transform = ColumnTransformer(
#      11     [
#      12         ("encoder", OrdinalEncoder(), cat_col),
#    (...)
#      15     ]
#      16 )
#      17 pipe = Pipeline(
#      18     steps=[
#      19         ("preprocessing", transform),
#      20         ("model", RandomForestClassifier(n_estimators=100, random_state=125)),
#      21     ]
#      22 )
# ---> 23 pipe.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.metrics import accuracy_score, f1_score

predictions = pipe.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
f1 = f1_score(y_test, predictions, average="macro")

print("Accuracy:", str(round(accuracy, 2) * 100) + "%", "F1:", round(f1, 2))
# Out:
# Accuracy: 95.0% F1: 0.92

# %%
with open("Results/metrics.txt", "w") as outfile:
    outfile.write(f"\nAccuracy = {round(accuracy, 2) * 100}% , F1 Score = {round(f1, 2)}.")

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(y_test, predictions, labels=pipe.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipe.classes_)
disp.plot()
plt.savefig("Results/model_results.png", dpi=120)

# %%
import skops.io as sio

sio.dump(pipe, "Model/drug_pipeline.skops")

# %%
untrusted_types = sio.get_untrusted_types(file="Model/drug_pipeline.skops")
print(untrusted_types)
sio.load("Model/drug_pipeline.skops", trusted=untrusted_types)
# Out:
# ['numpy.dtype']
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('encoder', OrdinalEncoder(),
#                                                   [1, 2, 3]),
#                                                  ('num_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   [0, 4]),
#                                                  ('num_scaler',
#                                                   StandardScaler(), [0, 4])])),
#                 ('model', RandomForestClassifier(random_state=125))])
